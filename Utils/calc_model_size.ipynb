# %%
model_number_of_params = 175 * 1e9
gpu_memory = 40 * (1024**3)  # in bytes
param_size = 2  # assuming fp16 = 2 bytes

# %%
model_size = model_number_of_params * param_size  # in bytes
print(f"Model size: {model_size / (1024 ** 3):.2f} GB")
# Out:
# Model size: 325.96 GB

# %%
batch_size = 1
seq_len = 100  # in tokens
hidden_size = 512

# %%
activation_size = batch_size * seq_len * hidden_size * 2 * param_size  # in bytes
print(f"Activation size: {activation_size / (1024 ** 2):.2f} MB")
# Out:
# Activation size: 0.39 MB
