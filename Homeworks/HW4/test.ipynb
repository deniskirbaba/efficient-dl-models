# %%
# %load_ext autoreload
# %autoreload 2

# %%
import q12
import torch

# %%
x = torch.tensor([[1, 2, 3], [4, 5, 6]], dtype=torch.int8, device=torch.device("cuda"))
x_scale = torch.tensor([1.0], device=torch.device("cuda"))
w = torch.tensor([[1, 1], [1, 1], [1, 1]], dtype=torch.int8, device=torch.device("cuda"))
w_scale = torch.tensor([1.0], device=torch.device("cuda"))

# %%
q12.matmul_int8_fused(x, x_scale, w, w_scale)
# Out:
# /home/deniskirbaba/dev/aith/git/efficient-dl-models/Homeworks/HW4/q12.py:106:27: error: 'arith.extf' op operand #0 must be floating-point-like, but got 'tensor<64x64xi8, #ttg.dot_op<{opIdx = 0, parent = #ttg.blocked<{sizePerThread = [4, 4], threadsPerWarp = [2, 16], warpsPerCTA = [4, 1], order = [1, 0]}>}>>'
#         acc += tl.dot(x_q, w_q, out_dtype=tl.int32)
#                           ^
# module {
#   tt.func public @_forward_int8_fused_kernel(%arg0: !tt.ptr<i8> {tt.divisibility = 16 : i32}, %arg1: !tt.ptr<f32> {tt.divisibility = 16 : i32}, %arg2: !tt.ptr<i8> {tt.divisibility = 16 : i32}, %arg3: !tt.ptr<f32> {tt.divisibility = 16 : i32}, %arg4: !tt.ptr<f16> {tt.divisibility = 16 : i32}, %arg5: i32, %arg6: i32, %arg7: i32) attributes {noinline = false} {
#     %cst = arith.constant dense<0> : tensor<64x64xi8>
#     %c0_i32 = arith.constant 0 : i32
#     %cst_0 = arith.constant dense<0> : tensor<64x64xi32>
#     %c64_i32 = arith.constant 64 : i32
# ...
