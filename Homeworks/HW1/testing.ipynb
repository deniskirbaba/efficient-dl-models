# %%
# !python 1.py
# Out:
# |        |   (64, nan) |   (64, 64.0) |   (256, nan) |   (256, 256.0) |
# |:-------|------------:|-------------:|-------------:|---------------:|
# | torch  |         nan |   0.00607392 |          nan |      0.0057681 |
# | triton |         nan |   0.0104686  |          nan |      0.0210335 |

# %%
# !python 2.py
# Out:
# |        |   (64, nan) |   (64, 64.0) |   (256, nan) |   (256, 256.0) |   (1024, nan) |   (1024, 1024.0) |
# |:-------|------------:|-------------:|-------------:|---------------:|--------------:|-----------------:|
# | torch  |         nan |   0.00540071 |          nan |     0.00544405 |           nan |        0.0101744 |
# | triton |         nan |   0.00535097 |          nan |     0.00648533 |           nan |        0.0307058 |

# %%
# !python 3.py
# Out:
# |        |   (32, 64) |   (64, 128) |   (256, 512) |
# |:-------|-----------:|------------:|-------------:|
# | torch  | 0.00630163 |   0.006296  |    0.0074708 |
# | triton | 0.0051448  |   0.0058464 |    0.0246106 |

# %%
# !python 4.py
# Out:
# |        |   (32, 64) |   (64, 128) |   (256, 512) |   (512, 1024) |
# |:-------|-----------:|------------:|-------------:|--------------:|
# | torch  | 0.00640533 |   0.006334  |     0.007414 |    0.00915119 |
# | triton | 0.00728992 |   0.0072996 |     0.007488 |    0.00775129 |

# %%
# !python 5.py
# Out:
# |        |   (32, 64) |   (64, 128) |   (256, 512) |   (512, 1024) |
# |:-------|-----------:|------------:|-------------:|--------------:|
# | torch  | 0.00914514 |  0.00918805 |    0.0107682 |     0.0130657 |
# | triton | 0.00924922 |  0.00947848 |    0.0111145 |     0.0100196 |

# %%
# !python 6.py
# Out:
# |        |   (10, 20) |   (32, 64) |   (64, 128) |   (256, 512) |   (512, 1024) |
# |:-------|-----------:|-----------:|------------:|-------------:|--------------:|
# | torch  |  0.373914  |  0.372109  |   0.367917  |    0.59354   |     0.358487  |
# | triton |  0.0111429 |  0.0106475 |   0.0108201 |    0.0125727 |     0.0137584 |

# %%
# !python 7.py
# Out:
# |        |   (10, 20) |   (32, 64) |   (64, 128) |   (256, 256) |
# |:-------|-----------:|-----------:|------------:|-------------:|
# | torch  | 0.00702489 | 0.00727818 |  0.0073843  |   0.00835889 |
# | triton | 0.0109229  | 0.00852456 |  0.00897823 |   0.0110789  |

# %%
# !python 8.py
# Out:
# |        |   (10, 20) |   (32, 64) |   (64, 128) |   (256, 256) |   (512, 1024) |
# |:-------|-----------:|-----------:|------------:|-------------:|--------------:|
# | torch  |  0.0211963 | 0.021664   |  0.022928   |    0.0229592 |     0.0380704 |
# | triton |  0.0190919 | 0.00873276 |  0.00902319 |    0.0142572 |     0.0413724 |

# %%
# !python 9.py
# Out:
# |        |        32 |       64 |       128 |       256 |       512 |     1024 |     2048 |
# |:-------|----------:|---------:|----------:|----------:|----------:|---------:|---------:|
# | torch  | 0.03372   | 0.102586 | 0.0670166 | 0.0944848 | 0.0430501 | 0.246658 | 0.361728 |
# | triton | 0.0725295 | 0.072465 | 0.0998839 | 0.0850785 | 0.206281  | 0.152888 | 0.494547 |
